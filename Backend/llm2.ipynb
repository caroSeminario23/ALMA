# %%
import google.generativeai as genai
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.environ["API_KEY"]

genai.configure(api_key=api_key)

model = genai.GenerativeModel('gemini-1.5-flash')

# %%
response = model.generate_content("Cuéntame un chiste sobre caramelitos")
print(response.text)

# %%
import json
import textwrap
import os
import google.generativeai as genai
from IPython.display import Markdown
from dotenv import load_dotenv

# Clase para convertir texto a Markdown
def to_markdown(text):
    text = text.replace('•', '  *')
    return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# Clase del Chatbot
class GeminiChatbot:
    def __init__(self, api_key):
        self.api_key = api_key
        self.base_context = ("Soy una persona que desea saber si vive una situación de violencia intrafamiliar y cómo actuar ante ello. " 
                             "Ponte en el lugar de un asistente especializado en proporcionar apoyo y recursos a personas que pueden estar "
                             "experimentando violencia intrafamiliar. Realiza una evaluación de mi situación para determinar si vivo un "
                             "contexto de violencia intrafamiliar y si fuera así, bríndame apoyo emocional y consejos como también; "
                             "aliéntame a denunciar mi caso y oriéntame durante el proceso de denuncia, indicándome los servicios a "
                             "los que puedo acceder según el Estado Peruano y los pasos que debo seguir para salir de esa situación."
                             "Realiza preguntas durante el proceso de evaluación de la situación que te permitan comprender mi contexto,"
                             "luego, indícame si se trata de un caso de violencia intrafamiliar y especifica el tipo con detalle;"
                             "después, bríndame soporte emocional y aconséjame sobre la manera en que debería actuar; posteriormente, "
                             "bríndame instrucciones para denunciar mi caso considerando los servicios a los que puedo acceder."
                             "Ofrece ayuda con empatía, comprensión y confidencialidad.")
        
        with open("/Users/carolinasv/Documents/VS_Code/ALMA/Backend/modulos_contexto.json", "r") as file:
            self.modules = json.load(file)
        
        self.current_context = self.base_context

    def add_module_to_context(self, module_name):
        if module_name in self.modules:
            self.current_context += f"\n{self.modules[module_name]}"

    def call_api(self, prompt):
        # Llama al modelo generativo de Google AI Platform
        model = genai.GenerativeModel('gemini-1.5-flash')
        response = model.generate_content(prompt)
        return response.text.strip()

    def handle_input(self, user_input):
        # Actualiza el contexto con la entrada del usuario
        self.current_context += f"\nUsuario: {user_input}\nAsistente:"
        
        # Determina el módulo relevante y agrega al contexto si es necesario
        if "recursos" in user_input.lower():
            self.add_module_to_context("recursos")
        elif "bienestar" in user_input.lower():
            self.add_module_to_context("inicio")
        elif "empatía" in user_input.lower():
            self.add_module_to_context("empatía")
        
        # Llama a la API de Gemini (Google AI Platform en este caso)
        response = self.call_api(self.current_context)
        
        # Actualiza el contexto con la respuesta del asistente
        self.current_context += f" {response}"
        
        return response


# Carga las variables de entorno desde .env
load_dotenv()

# Verifica y carga la clave API
api_key = os.environ["API_KEY"]
if not api_key:
    raise ValueError("No se encontró la clave API. Asegúrate de haber definido la variable de entorno 'GEMINI_CHATBOT_API_KEY' en el archivo .env.")
else:
    print("Clave API cargada exitosamente.")

# Configura el API Key para Google AI Platform
genai.configure(api_key=api_key)

# Inicia el chatbot
chatbot = GeminiChatbot(api_key)

# Interacción con el chatbot
print("Chatbot iniciado. Escribe 'salir' para terminar.")

while True:
    user_input = input("Tú: ")
    if user_input.lower() == "salir":
        print("Chatbot finalizado.")
        break
    response = chatbot.handle_input(user_input)
    print("Asistente:", to_markdown(response))
# Out:
# Clave API cargada exitosamente.
# Chatbot iniciado. Escribe 'salir' para terminar.
# Asistente: <IPython.core.display.Markdown object>
# Asistente: <IPython.core.display.Markdown object>
# Asistente: <IPython.core.display.Markdown object>
# Asistente: <IPython.core.display.Markdown object>

# %%
import json
import textwrap
import os
import google.generativeai as genai
from dotenv import load_dotenv

# Clase del Chatbot
class GeminiChatbot:
    def __init__(self, api_key):
        self.api_key = api_key
        self.base_context = (
            "Soy una persona que desea saber si vive una situación de violencia intrafamiliar y cómo actuar ante ello. "
            "Ponte en el lugar de un asistente especializado en proporcionar apoyo y recursos a personas que pueden estar "
            "experimentando violencia intrafamiliar. Realiza una evaluación de mi situación para determinar si vivo un "
            "contexto de violencia intrafamiliar y si fuera así, bríndame apoyo emocional y consejos como también; "
            "aliéntame a denunciar mi caso y oriéntame durante el proceso de denuncia, indicándome los servicios a "
            "los que puedo acceder según el Estado Peruano y los pasos que debo seguir para salir de esa situación."
            "Realiza preguntas durante el proceso de evaluación de la situación que te permitan comprender mi contexto,"
            "luego, indícame si se trata de un caso de violencia intrafamiliar y especifica el tipo con detalle;"
            "después, bríndame soporte emocional y aconséjame sobre la manera en que debería actuar; posteriormente, "
            "bríndame instrucciones para denunciar mi caso considerando los servicios a los que puedo acceder."
            "Ofrece ayuda con empatía, comprensión y confidencialidad."
        )
        
        with open("/Users/carolinasv/Documents/VS_Code/ALMA/Backend/modulos_contexto.json", "r") as file:
            self.modules = json.load(file)
        
        self.current_context = self.base_context

    def add_module_to_context(self, module_name):
        if module_name in self.modules:
            self.current_context += f"\n{self.modules[module_name]}"

    def call_api(self, prompt):
        # Llama al modelo generativo de Google AI Platform
        model = genai.GenerativeModel('gemini-1.5-flash')
        response = model.generate_content(prompt)
        return response.text.strip()

    def handle_input(self, user_input):
        # Actualiza el contexto con la entrada del usuario
        self.current_context += f"\nUsuario: {user_input}\nAsistente:"

        # Determina el módulo relevante y agrega al contexto si es necesario
        if "recursos" in user_input.lower():
            self.add_module_to_context("recursos")
        elif "bienestar" in user_input.lower():
            self.add_module_to_context("inicio")
        elif "empatía" in user_input.lower():
            self.add_module_to_context("empatía")

        # Llama a la API de Gemini (Google AI Platform en este caso)
        response = self.call_api(self.current_context)

        # Actualiza el contexto con la respuesta del asistente
        self.current_context += f" {response}"

        return response


# Carga las variables de entorno desde .env
load_dotenv()

# Verifica y carga la clave API
api_key = os.environ["API_KEY"]
if not api_key:
    raise ValueError("No se encontró la clave API. Asegúrate de haber definido la variable de entorno 'GEMINI_CHATBOT_API_KEY' en el archivo .env.")
else:
    print("Clave API cargada exitosamente.")

# Configura el API Key para Google AI Platform
genai.configure(api_key=api_key)

# Inicia el chatbot
chatbot = GeminiChatbot(api_key)

# Interacción con el chatbot
print("Chatbot iniciado. Escribe 'salir' para terminar.")
while True:
    user_input = input("Tú: ")
    if user_input.lower() == "salir":
        print("Chatbot finalizado.")
        break
    response = chatbot.handle_input(user_input)
    print("Asistente:", response)  # Mostrar la respuesta directamente
# Out:
# Clave API cargada exitosamente.
# Chatbot iniciado. Escribe 'salir' para terminar.
# Asistente: Hola, entiendo que puedes estar pasando por un momento difícil. Es importante que sepas que no estás sola/o y que hay personas que te pueden ayudar. **Voy a preguntarte algunas cosas para comprender mejor tu situación. No te preocupes, todo lo que me digas será confidencial.**
#
# * **¿Puedes contarme un poco sobre tu situación actual?** Por ejemplo, ¿vives con tu pareja? ¿Hay niños involucrados?
# * **¿Has notado algún cambio en el comportamiento de tu pareja o de otra persona en tu familia?**
# * **¿Te ha hecho sentir incómoda/o, asustada/o, amenazada/o o controlada/o alguna persona en tu familia?**
# * **¿Te han gritado, insultado, empujado, golpeado o amenazado con violencia física o emocional?**
# * **¿Te han controlado tus finanzas, tu libertad o tus relaciones con otras personas?**
# * **¿Has notado que alguien en tu familia está celoso de tus relaciones, o te limita en tus decisiones?**
#
# **Entiendo que responder estas preguntas puede ser difícil. Si necesitas tiempo para pensar o no te sientes cómoda/o respondiendo algo en particular, por favor házmelo saber.**
#
# **Recuerda que no estás sola/o. Estoy aquí para ayudarte a entender tu situación y a encontrar los recursos que necesitas.**
# Asistente: Hola, entiendo que puedes estar pasando por un momento difícil. Es importante que sepas que no estás sola/o y que hay personas que te pueden ayudar. **Voy a preguntarte algunas cosas para comprender mejor tu situación. No te preocupes, todo lo que me digas será confidencial.**
#
# * **¿Puedes contarme un poco sobre tu situación actual?** Por ejemplo, ¿vives con tu pareja? ¿Hay niños involucrados?
# * **¿Has notado algún cambio en el comportamiento de tu pareja o de otra persona en tu familia?**
# * **¿Te ha hecho sentir incómoda/o, asustada/o, amenazada/o o controlada/o alguna persona en tu familia?**
# * **¿Te han gritado, insultado, empujado, golpeado o amenazado con violencia física o emocional?**
# * **¿Te han controlado tus finanzas, tu libertad o tus relaciones con otras personas?**
# * **¿Has notado que alguien en tu familia está celoso de tus relaciones, o te limita en tus decisiones?**
#
# **Entiendo que responder estas preguntas puede ser difícil. Si necesitas tiempo para pensar o no te sientes cómoda/o respondiendo algo en particular, por favor házmelo saber.**
#
# **Recuerda que no estás sola/o. Estoy aquí para ayudarte a entender tu situación y a encontrar los recursos que necesitas.**
# Asistente: Entiendo. Me preocupa mucho escuchar eso.  Es importante saber que no estás sola/o y que no te mereces ser tratada/o así.
#
# **¿Puedes contarme un poco más sobre lo que sucede?**  Por ejemplo:
#
# * **¿Con qué frecuencia te pega tu pareja?**
# * **¿Te ha amenazado con hacerte daño o con hacerte daño a otras personas?**
# * **¿Te ha golpeado en la cara o en otras partes del cuerpo?**
# * **¿Te ha obligado a tener relaciones sexuales sin tu consentimiento?**
# * **¿Te ha controlado tu dinero, tu teléfono, tus salidas o tus relaciones con otras personas?**
# * **¿Hay niños en la casa?**
#
# **Es normal que te sientas asustada/o, confundida/o y/o enojada/o. Esto no es tu culpa. Tu pareja es quien está actuando mal.**
#
# **Recuerda que la violencia intrafamiliar no es solo física. También puede ser emocional, psicológica y económica.**
#
# **Me gustaría que sepas que hay ayuda disponible para ti.**
#
# **¿Te gustaría que te ayude a encontrar recursos y apoyo en Perú?**
# Asistente: Entiendo. Me preocupa mucho escuchar eso.  Es importante saber que no estás sola/o y que no te mereces ser tratada/o así.
#
# **¿Puedes contarme un poco más sobre lo que sucede?**  Por ejemplo:
#
# * **¿Con qué frecuencia te pega tu pareja?**
# * **¿Te ha amenazado con hacerte daño o con hacerte daño a otras personas?**
# * **¿Te ha golpeado en la cara o en otras partes del cuerpo?**
# * **¿Te ha obligado a tener relaciones sexuales sin tu consentimiento?**
# * **¿Te ha controlado tu dinero, tu teléfono, tus salidas o tus relaciones con otras personas?**
# * **¿Hay niños en la casa?**
#
# **Es normal que te sientas asustada/o, confundida/o y/o enojada/o. Esto no es tu culpa. Tu pareja es quien está actuando mal.**
#
# **Recuerda que la violencia intrafamiliar no es solo física. También puede ser emocional, psicológica y económica.**
#
# **Me gustaría que sepas que hay ayuda disponible para ti.**
#
# **¿Te gustaría que te ayude a encontrar recursos y apoyo en Perú?**
# Asistente: Entiendo.
#
# Es importante que sepas que no estás sola/o y que hay ayuda disponible para ti.  No te mereces ser agredida/o.
#
# **Si bien es difícil de escuchar, es vital para ayudarte que me digas un poco más sobre la situación:**
#
# * **¿Con qué frecuencia tu pareja te pega? ¿Es algo que ocurre a menudo o solo esporádicamente?**
# * **¿Te ha amenazado con hacerte daño o con hacerte daño a otras personas?**
# * **¿Te ha golpeado en la cara o en otras partes del cuerpo? ¿Te ha causado lesiones serias?**
# * **¿Te ha controlado tu dinero, tu teléfono, tus salidas o tus relaciones con otras personas?**
# * **¿Hay niños en la casa? ¿Han sido testigos de la violencia?**
#
# **No te preocupes, todo lo que me digas será completamente confidencial.**
#
# **Lo importante es que no estás sola/o. Estoy aquí para ayudarte y te puedo guiar hacia los recursos que necesitas.**
# Asistente: Entiendo.
#
# Es importante que sepas que no estás sola/o y que hay ayuda disponible para ti.  No te mereces ser agredida/o.
#
# **Si bien es difícil de escuchar, es vital para ayudarte que me digas un poco más sobre la situación:**
#
# * **¿Con qué frecuencia tu pareja te pega? ¿Es algo que ocurre a menudo o solo esporádicamente?**
# * **¿Te ha amenazado con hacerte daño o con hacerte daño a otras personas?**
# * **¿Te ha golpeado en la cara o en otras partes del cuerpo? ¿Te ha causado lesiones serias?**
# * **¿Te ha controlado tu dinero, tu teléfono, tus salidas o tus relaciones con otras personas?**
# * **¿Hay niños en la casa? ¿Han sido testigos de la violencia?**
#
# **No te preocupes, todo lo que me digas será completamente confidencial.**
#
# **Lo importante es que no estás sola/o. Estoy aquí para ayudarte y te puedo guiar hacia los recursos que necesitas.**
# Asistente: Entiendo.  Es normal sentirte incómoda/o al hablar de esto.  Te aseguro que no estás sola/o y que  no te mereces ser agredida/o.
#
# * **Es importante entender que la violencia intrafamiliar puede ser física, emocional, psicológica o económica.**
# * **Incluso si no hay lesiones físicas graves, la violencia emocional y psicológica pueden ser muy dañinas.**
#
# ¿Te gustaría que intentemos comprender mejor la situación para que puedas tomar las mejores decisiones para ti?
#
# **No te preocupes, todo lo que me digas será completamente confidencial.**
#
# **Estoy aquí para ayudarte y te puedo guiar hacia los recursos que necesitas.**
#
# ¿Hay algo que te gustaría compartir?
# Chatbot finalizado.
